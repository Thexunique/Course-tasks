# %% [markdown]
# #Final project for Python & AI course
# ##Made by:-  Eng\Nader Mohammed Elsaid Salama
# ##Lecturer: Eng: Amr Hany

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('experience_salary_dataset.csv')

# %%
x=df.iloc[:,0].values.reshape(-1,1)
y=df.iloc[:,1].values.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prideted = model.predict(x_test)
print(prideted)
# Out:
# [[27866.40806045]
#  [31741.51097517]
#  [16241.0993163 ]
#  [ 8490.89348687]
#  [31741.51097517]
#  [12365.99640158]
#  [ 8490.89348687]
#  [12365.99640158]
#  [39491.71680461]
#  [27866.40806045]]

# %%
r2_score(y_test,prideted)
# Out:
# 0.9697918566509427

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,model.predict(x_train),color='blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
model.predict([[6]])
# Out:
# array([[23991.30514574]])
